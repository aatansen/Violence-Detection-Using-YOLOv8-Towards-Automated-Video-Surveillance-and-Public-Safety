# %% [markdown]
# # Update 01

# %% [markdown]
# ## Violence non-violence detection

# %% [markdown]
# ### Machine configuration

# %%
# !nvidia-smi
# Out:
# Thu Jul 20 03:29:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ### Installing YoloV8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 4.9 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.3/78.2 GB disk)

# %% [markdown]
# ### Importing necessary libraries

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ### Training with custom dataset

# %%
# !ls
# Out:
# drive

# %%
# %cd /content/drive/MyDrive/thesis
# Out:
# /content/drive/MyDrive/thesis

# %%
# %cd /content/drive/MyDrive/thesis/

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=416 plots=True
# Out:
# /content/drive/MyDrive/thesis
# ...
# 100% 21.5M/21.5M [00:00<00:00, 72.9MB/s]
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Traning result

# %% [markdown]
# #### Result data

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/thesis/runs/detect/train/results.csv')
df
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         0                   1.5598                  1.95730
# 1                         1                   1.6407                  1.95190
# 2                         2                   1.6949                  1.94530
# 3                         3                   1.6726                  1.87240
# 4                         4                   1.6115                  1.81880
# 5                         5                   1.5989                  1.78190
# 6                         6                   1.5580                  1.70560
# 7                         7                   1.5248                  1.69060
# 8                         8                   1.5160                  1.60190
# 9                         9                   1.4494                  1.55140
# 10                       10                   1.4276                  1.48050
# ...

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/results.png', width=600)

# %% [markdown]
# #### Confusion matrix

# %%
display(Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/confusion_matrix.png', width=600) , Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/confusion_matrix_normalized.png', width=600))

# %% [markdown]
# #### F1 Confidence Curve

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/F1_curve.png', width=600)

# %% [markdown]
# #### Precision Recall Curve

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/PR_curve.png', width=600)

# %% [markdown]
# #### Precision Confidence Curve

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/P_curve.png', width=600)

# %% [markdown]
# #### Recall Confidence Curve

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/R_curve.png', width=600)

# %% [markdown]
# #### Training images

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/train/train_batch1861.jpg', width=600)

# %% [markdown]
# ### Validation

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/thesis/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/thesis/dataset/roboflow/valid/labels.cache... 575 images, 0 backgrounds, 0 corrupt: 100% 575/575 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 36/36 [00:10<00:00,  3.44it/s]
#                    all        575        978      0.863      0.819      0.884      0.586
#            NonViolence        575        430      0.831      0.768      0.848      0.556
#               Violence        575        548      0.895       0.87       0.92      0.615
# Speed: 0.5ms preprocess, 4.7ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# ### Validation result

# %% [markdown]
# #### Confusion matrix

# %%
display(Image(filename='/content/drive/MyDrive/thesis/runs/detect/val/confusion_matrix.png', width=600) , Image(filename='/content/drive/MyDrive/thesis/runs/detect/val/confusion_matrix_normalized.png', width=600))

# %% [markdown]
# #### Validation images

# %%
Image(filename='/content/drive/MyDrive/thesis/runs/detect/val/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ### Predict on test data (images)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/thesis/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/thesis/dataset/roboflow/test/images
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# image 1/290 /content/drive/MyDrive/thesis/dataset/roboflow/test/images/NV_118_F44_jpg.rf.53f9248d0de24bb3b608bdc4cce78bd4.jpg: 416x416 2 NonViolences, 10.5ms
# image 2/290 /content/drive/MyDrive/thesis/dataset/roboflow/test/images/NV_118_F72_jpg.rf.8e0cf97451cba97e942718e6b5021bb9.jpg: 416x416 2 NonViolences, 10.6ms
# image 3/290 /content/drive/MyDrive/thesis/dataset/roboflow/test/images/NV_137_F100_jpg.rf.b9ffa3cd0ec141ba4a5b1e23203f6301.jpg: 416x416 1 NonViolence, 31.6ms
# image 4/290 /content/drive/MyDrive/thesis/dataset/roboflow/test/images/NV_140_F24_jpg.rf.67bf6a0891129ef0fc5bf8a922da32a8.jpg: 416x416 1 NonViolence, 10.9ms
# image 5/290 /content/drive/MyDrive/thesis/dataset/roboflow/test/images/NV_140_F28_jpg.rf.52aef7839c94aadc0f1830e207c8c2ee.jpg: 416x416 1 NonViolence, 10.6ms
# ...

# %% [markdown]
# #### Predicted images

# %%
import glob
import random
from IPython.display import Image, display

# Get the list of all image paths in the directory
image_paths = glob.glob('/content/drive/MyDrive/thesis/runs/detect/predict/*.jpg')

# Randomly select three image paths from the list
random_image_paths = random.sample(image_paths, 3)

# Display the three randomly selected images
for image_path in random_image_paths:
    display(Image(filename=image_path, width=416))
    print("\n")

# %% [markdown]
# ### Predict on test data (Videos)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/thesis/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/thesis/dataset/mixed_videos
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients
#
# video 1/10 (1/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 (no detections), 145.4ms
# video 1/10 (2/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 (no detections), 14.0ms
# video 1/10 (3/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 1 Violence, 8.4ms
# video 1/10 (4/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 1 Violence, 22.3ms
# video 1/10 (5/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 1 Violence, 19.6ms
# video 1/10 (6/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 (no detections), 15.3ms
# video 1/10 (7/66) /content/drive/MyDrive/thesis/dataset/mixed_videos/NV_1.mp4: 256x416 (no detections), 20.1ms
# ...
